# %% [markdown]
# <h2>Analise da tabela do Campeonato Brasileiro de 2003 a 2022</h2>

# %% [markdown]
# Legenda:
#
# Contagem de vitorias por equipe
#
# Qual equipe venceu o campeonato mais vezes ao longo dos anos?
#
# Qual equipe teve o desempenho mais consistente ao longo dos anos?
#
# Qual equipe teve a maior pontuação média por partida ao longo dos anos?
#
# Quais equipes tiveram o pior desempenho geral durante o período de 2003 a 2022?

# %%
#Importando a biblioteca pandas 
import pandas as pd

# %%
# criando uma variável para receber o dataset em csv
brasileirao = pd.read_excel('brasileirao2.xlsx')

# %%
#Analisando o conjunto de dados
brasileirao.head()
# Out:
#     ano  posicao       equipe  pontos  jogos  vitorias  empates  derrotas  \
# 0  2003        1     Cruzeiro     100     46        31        7         8
# 1  2003        2       Santos      87     46        25       12         9
# 2  2003        3    São Paulo      78     46        22       12        12
# 3  2003        4  São Caetano      74     46        19       14        13
# 4  2003        5     Coritiba      73     46        21       10        15
#
#    gols_marcados  gols_sofridos  saldo_de_gols  total_de_pontos  \
# 0            102             47             55              138
# 1             93             60             33              138
# 2             81             67             14              138
# 3             53             37             16              138
# 4             67             58              9              138
#
#    aproveitamento
# 0           72.46
# 1           63.04
# 2           56.52
# 3           53.62
# 4           52.90

# %%
brasileirao.tail()
# Out:
#       ano  posicao               equipe  pontos  jogos  vitorias  empates  \
# 405  2022       16               Cuiabá      41     38        10       11
# 406  2022       17                Ceará      37     38         7       16
# 407  2022       18  Atlético Goianiense      36     38         8       12
# 408  2022       19                 Avaí      35     38         9        8
# 409  2022       20            Juventude      22     38         3       13
#
#      derrotas  gols_marcados  gols_sofridos  saldo_de_gols  total_de_pontos  \
# 405        17             31             42            -11              114
# 406        15             34             41             -7              114
# 407        18             39             57            -18              114
# 408        21             34             60            -26              114
# 409        22             29             69            -40              114
#
#      aproveitamento
# 405           35.96
# 406           32.46
# ...

# %% [markdown]
# <h5>Verificar times duplicados ou com escrita incorreta</h5>

# %%
equipes_diferentes = brasileirao['equipe'].nunique()
equipes_diferentes
# Out:
# 50

# %%
equipes_totais = brasileirao['equipe'].value_counts()

# %%
equipes_totais
# Out:
# São Paulo                 20
# Santos                    20
# Flamengo                  20
# Fluminense                20
# Corinthians               19
# Internacional             19
# Atlético Mineiro          19
# Grêmio                    18
# Cruzeiro                  17
# Palmeiras                 17
# Botafogo                  17
# Atlético Paranaense       15
# Vasco da Gama             15
# Coritiba                  14
# Goiás                     14
# Figueirense               11
# Bahia                     10
# Vitória                   10
# Ponte Preta                9
# Sport                      9
# Juventude                  7
# Chapecoense                7
# Avaí                       7
# Atlético Goianiense        7
# Ceará                      7
# Fortaleza                  7
# Paraná                     6
# Náutico                    5
# América Mineiro            5
# Criciúma                   4
# São Caetano                4
# Guarani                    3
# ...

# %%
equipes_totaisDF = pd.DataFrame(equipes_totais)
equipes_totaisDF
# Out:
#                         equipe
# São Paulo                   20
# Santos                      20
# Flamengo                    20
# Fluminense                  20
# Corinthians                 19
# Internacional               19
# Atlético Mineiro            19
# Grêmio                      18
# Cruzeiro                    17
# Palmeiras                   17
# Botafogo                    17
# Atlético Paranaense         15
# Vasco da Gama               15
# Coritiba                    14
# Goiás                       14
# Figueirense                 11
# Bahia                       10
# Vitória                     10
# Ponte Preta                  9
# Sport                        9
# Juventude                    7
# Chapecoense                  7
# Avaí                         7
# Atlético Goianiense          7
# Ceará                        7
# Fortaleza                    7
# Paraná                       6
# Náutico                      5
# América Mineiro              5
# ...

# %%
brasileirao.loc[brasileirao['equipe'] == 'Palmeirasa?']
# Out:
#       ano  posicao       equipe  pontos  jogos  vitorias  empates  derrotas  \
# 372  2021        3  Palmeirasa?      66     38        20        6        12
#
#      gols_marcados  gols_sofridos  saldo_de_gols  total_de_pontos  \
# 372             58             43             15              114
#
#      aproveitamento
# 372           57.89

# %%
brasileirao.loc[brasileirao['ano'] == 2021]
# Out:
#       ano  posicao                  equipe  pontos  jogos  vitorias  empates  \
# 370  2021        1        Atlético Mineiro      84     38        26        6
# 371  2021        2                Flamengo      71     38        21        8
# 372  2021        3             Palmeirasa?      66     38        20        6
# 373  2021        4               Fortaleza      58     38        17        7
# 374  2021        5             Corinthians      57     38        15       12
# 375  2021        6           RB Bragantino      56     38        14       14
# 376  2021        7              Fluminense      54     38        15        9
# 377  2021        8         América Mineiro      53     38        13       14
# 378  2021        9     Atlético Goianiense      53     38        13       14
# 379  2021       10                  Santos      50     38        12       14
# 380  2021       11                   Ceará      50     38        11       17
# ...

# %%
brasileirao.loc[brasileirao['equipe'] == 'Palmeirasa?', 'equipe'] = 'Palmeiras'

# %%
brasileirao.loc[brasileirao['ano'] == 2021]
# Out:
#       ano  posicao                  equipe  pontos  jogos  vitorias  empates  \
# 370  2021        1        Atlético Mineiro      84     38        26        6
# 371  2021        2                Flamengo      71     38        21        8
# 372  2021        3               Palmeiras      66     38        20        6
# 373  2021        4               Fortaleza      58     38        17        7
# 374  2021        5             Corinthians      57     38        15       12
# 375  2021        6           RB Bragantino      56     38        14       14
# 376  2021        7              Fluminense      54     38        15        9
# 377  2021        8         América Mineiro      53     38        13       14
# 378  2021        9     Atlético Goianiense      53     38        13       14
# 379  2021       10                  Santos      50     38        12       14
# 380  2021       11                   Ceará      50     38        11       17
# ...

# %%
brasileirao.loc[brasileirao['equipe'] == 'Athletico Paranaenseb?', 'equipe'] = 'Athletico Paranaense'

# %%
brasileirao.loc[brasileirao['ano'] == 2021]
# Out:
#       ano  posicao                equipe  pontos  jogos  vitorias  empates  \
# 370  2021        1      Atlético Mineiro      84     38        26        6
# 371  2021        2              Flamengo      71     38        21        8
# 372  2021        3             Palmeiras      66     38        20        6
# 373  2021        4             Fortaleza      58     38        17        7
# 374  2021        5           Corinthians      57     38        15       12
# 375  2021        6         RB Bragantino      56     38        14       14
# 376  2021        7            Fluminense      54     38        15        9
# 377  2021        8       América Mineiro      53     38        13       14
# 378  2021        9   Atlético Goianiense      53     38        13       14
# 379  2021       10                Santos      50     38        12       14
# 380  2021       11                 Ceará      50     38        11       17
# ...

# %%
equipes_totaisDF2 = pd.DataFrame(equipes_totais)
equipes_totaisDF2
# Out:
#                         equipe
# São Paulo                   20
# Santos                      20
# Flamengo                    20
# Fluminense                  20
# Corinthians                 19
# Internacional               19
# Atlético Mineiro            19
# Grêmio                      18
# Cruzeiro                    17
# Palmeiras                   17
# Botafogo                    17
# Atlético Paranaense         15
# Vasco da Gama               15
# Coritiba                    14
# Goiás                       14
# Figueirense                 11
# Bahia                       10
# Vitória                     10
# Ponte Preta                  9
# Sport                        9
# Juventude                    7
# Chapecoense                  7
# Avaí                         7
# Atlético Goianiense          7
# Ceará                        7
# Fortaleza                    7
# Paraná                       6
# Náutico                      5
# América Mineiro              5
# ...

# %%
equipes_diferentes = brasileirao['equipe'].nunique()
equipes_diferentes
# Out:
# 48

# %%
brasileirao.loc[brasileirao['equipe'] == 'Palmeiras']
# Out:
#       ano  posicao     equipe  pontos  jogos  vitorias  empates  derrotas  \
# 27   2004        4  Palmeiras      79     46        22       13        11
# 51   2005        4  Palmeiras      70     42        20       10        12
# 85   2006       16  Palmeiras      44     38        12        8        18
# 96   2007        7  Palmeiras      58     38        16       10        12
# 113  2008        4  Palmeiras      65     38        19        8        11
# 134  2009        5  Palmeiras      62     38        17       11        10
# 159  2010       10  Palmeiras      50     38        12       14        12
# 180  2011       11  Palmeiras      50     38        11       17        10
# 207  2012       18  Palmeiras      34     38         9        7        22
# 245  2014       16  Palmeiras      40     38        11        7        20
# 258  2015        9  Palmeiras      53     38        15        8        15
# 270  2016        1  Palmeiras      80     38        24        8         6
# ...

# %%
brasileirao.loc[brasileirao['equipe'] == 'Athletico Paranaense']
# Out:
#       ano  posicao                equipe  pontos  jogos  vitorias  empates  \
# 334  2019        5  Athletico Paranaense      64     38        18       10
# 358  2020        9  Athletico Paranaense      53     38        15        8
# 383  2021       14  Athletico Paranaense      47     38        13        8
# 395  2022        6  Athletico Paranaense      58     38        16       10
#
#      derrotas  gols_marcados  gols_sofridos  saldo_de_gols  total_de_pontos  \
# 334        10             51             32             19              114
# 358        15             38             36              2              114
# 383        17             41             45             -4              114
# 395        12             48             48              0              114
#
#      aproveitamento
# 334           56.14
# 358           46.49
# 383           41.23
# 395           50.88

# %%
brasileirao.loc[brasileirao['equipe'] == 'Atlético Paranaense']
# Out:
#       ano  posicao               equipe  pontos  jogos  vitorias  empates  \
# 11   2003       12  Atlético Paranaense      61     46        17       10
# 25   2004        2  Atlético Paranaense      86     46        25       11
# 53   2005        6  Atlético Paranaense      61     42        18        7
# 82   2006       13  Atlético Paranaense      48     38        13        9
# 101  2007       12  Atlético Paranaense      54     38        14       12
# 122  2008       13  Atlético Paranaense      45     38        12        9
# 143  2009       14  Atlético Paranaense      48     38        13        9
# 154  2010        5  Atlético Paranaense      60     38        17        9
# 186  2011       17  Atlético Paranaense      41     38        10       11
# 212  2013        3  Atlético Paranaense      64     38        18       10
# 237  2014        8  Atlético Paranaense      54     38        15        9
# 259  2015       10  Atlético Paranaense      51     38        14        9
# ...

# %%
brasileirao.loc[brasileirao['equipe'] == 'Atlético Paranaense', 'equipe'] = 'Athletico Paranaense'

# %%
brasileirao.loc[brasileirao['equipe'] == 'Athletico Paranaense']
# Out:
#       ano  posicao                equipe  pontos  jogos  vitorias  empates  \
# 11   2003       12  Athletico Paranaense      61     46        17       10
# 25   2004        2  Athletico Paranaense      86     46        25       11
# 53   2005        6  Athletico Paranaense      61     42        18        7
# 82   2006       13  Athletico Paranaense      48     38        13        9
# 101  2007       12  Athletico Paranaense      54     38        14       12
# 122  2008       13  Athletico Paranaense      45     38        12        9
# 143  2009       14  Athletico Paranaense      48     38        13        9
# 154  2010        5  Athletico Paranaense      60     38        17        9
# 186  2011       17  Athletico Paranaense      41     38        10       11
# 212  2013        3  Athletico Paranaense      64     38        18       10
# 237  2014        8  Athletico Paranaense      54     38        15        9
# ...

# %%
equipes_diferentes = brasileirao['equipe'].nunique()
equipes_diferentes
# Out:
# 47

# %% [markdown]
# <h5>Contagem de vitorias por equipe</h5>

# %%
contagem_vitorias = brasileirao.groupby('equipe')['vitorias'].sum()
contagem_vitorias
# Out:
# equipe
# América Mineiro          53
# América de Natal          4
# Athletico Paranaense    295
# Atlético Goianiense      72
# Atlético Mineiro        308
# Avaí                     66
# Bahia                   115
# Botafogo                229
# Brasiliense              10
# CSA                       8
# Ceará                    72
# Chapecoense              70
# Corinthians             314
# Coritiba                181
# Criciúma                 50
# Cruzeiro                293
# Cuiabá                   20
# Figueirense             142
# Flamengo                335
# Fluminense              306
# Fortaleza                93
# Goiás                   200
# Grêmio                  295
# Grêmio Barueri           12
# Grêmio Prudente           7
# Guarani                  36
# Internacional           324
# Ipatinga                  9
# Joinville                 7
# Juventude                85
# Náutico                  54
# Palmeiras               309
# Paraná                   83
# ...

# %%
contagem_vitoriasDF = pd.DataFrame(contagem_vitorias)
contagem_vitoriasDF = pd.DataFrame(contagem_vitorias.sort_values(ascending=False))
contagem_vitoriasDF
# Out:
#                       vitorias
# equipe
# São Paulo                  351
# Flamengo                   335
# Santos                     329
# Internacional              324
# Corinthians                314
# Palmeiras                  309
# Atlético Mineiro           308
# Fluminense                 306
# Athletico Paranaense       295
# Grêmio                     295
# Cruzeiro                   293
# Botafogo                   229
# Goiás                      200
# Vasco da Gama              197
# Coritiba                   181
# Figueirense                142
# Vitória                    123
# Bahia                      115
# Ponte Preta                114
# Sport                      110
# Fortaleza                   93
# Juventude                   85
# Paraná                      83
# Ceará                       72
# Atlético Goianiense         72
# Chapecoense                 70
# Avaí                        66
# São Caetano                 65
# Náutico                     54
# ...

# %% [markdown]
# <h5>Qual equipe venceu o campeonato mais vezes ao longo dos anos?</h5>

# %%
brasileirao.head()
# Out:
#     ano  posicao       equipe  pontos  jogos  vitorias  empates  derrotas  \
# 0  2003        1     Cruzeiro     100     46        31        7         8
# 1  2003        2       Santos      87     46        25       12         9
# 2  2003        3    São Paulo      78     46        22       12        12
# 3  2003        4  São Caetano      74     46        19       14        13
# 4  2003        5     Coritiba      73     46        21       10        15
#
#    gols_marcados  gols_sofridos  saldo_de_gols  total_de_pontos  \
# 0            102             47             55              138
# 1             93             60             33              138
# 2             81             67             14              138
# 3             53             37             16              138
# 4             67             58              9              138
#
#    aproveitamento
# 0           72.46
# 1           63.04
# 2           56.52
# 3           53.62
# 4           52.90

# %%
campeoes = brasileirao.loc[brasileirao['posicao'] == 1]
campeoes
# Out:
#       ano  posicao            equipe  pontos  jogos  vitorias  empates  \
# 0    2003        1          Cruzeiro     100     46        31        7
# 24   2004        1            Santos      89     46        27        8
# 48   2005        1       Corinthians      81     42        24        9
# 70   2006        1         São Paulo      78     38        22       12
# 90   2007        1         São Paulo      77     38        23        8
# 110  2008        1         São Paulo      75     38        21       12
# 130  2009        1          Flamengo      67     38        19       10
# 150  2010        1        Fluminense      71     38        20       11
# 170  2011        1       Corinthians      71     38        21        8
# 190  2012        1        Fluminense      77     38        22       11
# 210  2013        1          Cruzeiro      76     38        23        7
# 230  2014        1          Cruzeiro      80     38        24        8
# ...

# %%
maiores_campeoes = pd.DataFrame(campeoes['equipe'][campeoes['posicao'] == 1].value_counts())
maiores_campeoes
# Out:
#                   equipe
# Corinthians            4
# Cruzeiro               3
# São Paulo              3
# Flamengo               3
# Palmeiras              3
# Fluminense             2
# Santos                 1
# Atlético Mineiro       1

# %% [markdown]
# <h5>Qual equipe teve o desempenho mais consistente ao longo dos anos?</h5>

# %%
brasileirao
# Out:
#       ano  posicao               equipe  pontos  jogos  vitorias  empates  \
# 0    2003        1             Cruzeiro     100     46        31        7
# 1    2003        2               Santos      87     46        25       12
# 2    2003        3            São Paulo      78     46        22       12
# 3    2003        4          São Caetano      74     46        19       14
# 4    2003        5             Coritiba      73     46        21       10
# ..    ...      ...                  ...     ...    ...       ...      ...
# 405  2022       16               Cuiabá      41     38        10       11
# 406  2022       17                Ceará      37     38         7       16
# 407  2022       18  Atlético Goianiense      36     38         8       12
# 408  2022       19                 Avaí      35     38         9        8
# 409  2022       20            Juventude      22     38         3       13
#
#      derrotas  gols_marcados  gols_sofridos  saldo_de_gols  total_de_pontos  \
# ...

# %%
equipes_consistentes = pd.DataFrame(brasileirao.groupby('equipe')['posicao'].mean().sort_values())
equipes_consistentes
# Out:
#                         posicao
# equipe
# São Paulo              5.850000
# Internacional          6.473684
# Palmeiras              6.777778
# Corinthians            6.947368
# Santos                 7.100000
# Cruzeiro               7.235294
# Flamengo               7.350000
# Grêmio                 7.666667
# RB Bragantino          8.000000
# Atlético Mineiro       8.473684
# Athletico Paranaense   9.105263
# Fluminense             9.450000
# Grêmio Barueri        11.000000
# Botafogo              11.000000
# Goiás                 11.142857
# Vasco da Gama         12.333333
# Paraná                12.666667
# Fortaleza             13.000000
# Coritiba              13.500000
# Figueirense           13.545455
# Red Bull Bragantino   14.000000
# Sport                 14.000000
# Ceará                 14.285714
# Chapecoense           14.428571
# São Caetano           14.500000
# América Mineiro       14.800000
# Bahia                 14.900000
# Vitória               15.200000
# ...

# %% [markdown]
# <h5>Qual equipe teve a maior pontuação média por partida ao longo dos anos?</h5>

# %% [markdown]
# <h5>Quais equipes tiveram o pior desempenho geral durante o período de 2003 a 2022?</h5>

# %%
brasileirao.head()
# Out:
#     ano  posicao       equipe  pontos  jogos  vitorias  empates  derrotas  \
# 0  2003        1     Cruzeiro     100     46        31        7         8
# 1  2003        2       Santos      87     46        25       12         9
# 2  2003        3    São Paulo      78     46        22       12        12
# 3  2003        4  São Caetano      74     46        19       14        13
# 4  2003        5     Coritiba      73     46        21       10        15
#
#    gols_marcados  gols_sofridos  saldo_de_gols  total_de_pontos  \
# 0            102             47             55              138
# 1             93             60             33              138
# 2             81             67             14              138
# 3             53             37             16              138
# 4             67             58              9              138
#
#    aproveitamento
# 0           72.46
# 1           63.04
# 2           56.52
# 3           53.62
# 4           52.90

# %%
media_classificacao = brasileirao[(brasileirao['ano'] >= 2003) & (brasileirao['ano'] <= 2022)].groupby('equipe')['posicao'].mean()
media_classificacao
# Out:
# equipe
# América Mineiro         14.800000
# América de Natal        20.000000
# Athletico Paranaense     9.105263
# Atlético Goianiense     15.428571
# Atlético Mineiro         8.473684
# Avaí                    16.428571
# Bahia                   14.900000
# Botafogo                11.000000
# Brasiliense             22.000000
# CSA                     18.000000
# Ceará                   14.285714
# Chapecoense             14.428571
# Corinthians              6.947368
# Coritiba                13.500000
# Criciúma                17.250000
# Cruzeiro                 7.235294
# Cuiabá                  15.500000
# Figueirense             13.545455
# Flamengo                 7.350000
# Fluminense               9.450000
# Fortaleza               13.000000
# Goiás                   11.142857
# Grêmio                   7.666667
# Grêmio Barueri          11.000000
# Grêmio Prudente         20.000000
# Guarani                 17.666667
# Internacional            6.473684
# ...

# %%
pior_desempenho = pd.DataFrame(media_classificacao.sort_values(ascending=False))
pior_desempenho
# Out:
#                         posicao
# equipe
# Brasiliense           22.000000
# Grêmio Prudente       20.000000
# América de Natal      20.000000
# Ipatinga              20.000000
# Joinville             20.000000
# Santa Cruz            19.500000
# Paysandu              19.000000
# Santo André           18.000000
# CSA                   18.000000
# Guarani               17.666667
# Portuguesa            17.333333
# Criciúma              17.250000
# Sport Recife          17.000000
# Avaí                  16.428571
# Náutico               16.400000
# Cuiabá                15.500000
# Atlético Goianiense   15.428571
# Juventude             15.285714
# Ponte Preta           15.222222
# Vitória               15.200000
# Bahia                 14.900000
# América Mineiro       14.800000
# São Caetano           14.500000
# Chapecoense           14.428571
# Ceará                 14.285714
# Sport                 14.000000
# Red Bull Bragantino   14.000000
# Figueirense           13.545455
# ...

# %% [markdown]
# <h5>Qual foi o ano com o maior número de empates?</h5>

# %%
brasileirao
# Out:
#       ano  posicao               equipe  pontos  jogos  vitorias  empates  \
# 0    2003        1             Cruzeiro     100     46        31        7
# 1    2003        2               Santos      87     46        25       12
# 2    2003        3            São Paulo      78     46        22       12
# 3    2003        4          São Caetano      74     46        19       14
# 4    2003        5             Coritiba      73     46        21       10
# ..    ...      ...                  ...     ...    ...       ...      ...
# 405  2022       16               Cuiabá      41     38        10       11
# 406  2022       17                Ceará      37     38         7       16
# 407  2022       18  Atlético Goianiense      36     38         8       12
# 408  2022       19                 Avaí      35     38         9        8
# 409  2022       20            Juventude      22     38         3       13
#
#      derrotas  gols_marcados  gols_sofridos  saldo_de_gols  total_de_pontos  \
# ...

# %%
maior_ano_empates = brasileirao.groupby('ano')['empates'].sum().idxmax()
maior_ano_empates
# Out:
# 2003

# %%
total_empates_por_ano = brasileirao.groupby('ano')['empates'].sum().reset_index()
total_empates_por_ano
# Out:
#      ano  empates
# 0   2003      284
# 1   2004      280
# 2   2005      204
# 3   2006      194
# 4   2007      180
# 5   2008      192
# 6   2009      204
# 7   2010      236
# 8   2011      210
# 9   2012      210
# 10  2013      216
# 11  2014      184
# 12  2015      182
# 13  2016      188
# 14  2017      206
# 15  2018      220
# 16  2019      196
# 17  2020      216
# 18  2021      226
# 19  2022      216

# %%
contagem_vitoriasDF = pd.DataFrame(contagem_vitorias)
contagem_vitoriasDF = pd.DataFrame(contagem_vitorias.sort_values(ascending=False))
contagem_vitoriasDF
# Out:
#                       vitorias
# equipe
# São Paulo                  351
# Flamengo                   335
# Santos                     329
# Internacional              324
# Corinthians                314
# Palmeiras                  309
# Atlético Mineiro           308
# Fluminense                 306
# Athletico Paranaense       295
# Grêmio                     295
# Cruzeiro                   293
# Botafogo                   229
# Goiás                      200
# Vasco da Gama              197
# Coritiba                   181
# Figueirense                142
# Vitória                    123
# Bahia                      115
# Ponte Preta                114
# Sport                      110
# Fortaleza                   93
# Juventude                   85
# Paraná                      83
# Ceará                       72
# Atlético Goianiense         72
# Chapecoense                 70
# Avaí                        66
# São Caetano                 65
# Náutico                     54
# ...

# %%
total_empates_por_ano = total_empates_por_ano.rename(columns={'empates': 'total_empates'}).sort_values(by='total_empates', ascending=False)
total_empates_por_ano
# Out:
#      ano  total_empates
# 0   2003            284
# 1   2004            280
# 7   2010            236
# 18  2021            226
# 15  2018            220
# 17  2020            216
# 10  2013            216
# 19  2022            216
# 8   2011            210
# 9   2012            210
# 14  2017            206
# 6   2009            204
# 2   2005            204
# 16  2019            196
# 3   2006            194
# 5   2008            192
# 13  2016            188
# 11  2014            184
# 12  2015            182
# 4   2007            180

# %%
import matplotlib.pyplot as plt

# %%
media_gols_por_ano = brasileirao.groupby('ano')['gols_por_partida'].mean().reset_index()

# Crie um gráfico de linha para visualizar as tendências ao longo do tempo
plt.figure(figsize=(10, 6))
plt.plot(media_gols_por_ano['ano'], media_gols_por_ano['gols_por_partida'], marker='o', linestyle='-', color='b')
plt.title('Média de Gols por Partida ao Longo dos Anos')
plt.xlabel('Ano')
plt.ylabel('Média de Gols por Partida')
plt.grid(True)
plt.show()
