# %%
import pandas as pd

# %%
brasileirao = pd.read_excel('brasileirao2.xlsx')

# %%
brasileirao
# Out:
#       ano  posicao               equipe  pontos  jogos  vitorias  empates  \
# 0    2003        1             Cruzeiro     100     46        31        7
# 1    2003        2               Santos      87     46        25       12
# 2    2003        3            São Paulo      78     46        22       12
# 3    2003        4          São Caetano      74     46        19       14
# 4    2003        5             Coritiba      73     46        21       10
# ..    ...      ...                  ...     ...    ...       ...      ...
# 405  2022       16               Cuiabá      41     38        10       11
# 406  2022       17                Ceará      37     38         7       16
# 407  2022       18  Atlético Goianiense      36     38         8       12
# 408  2022       19                 Avaí      35     38         9        8
# 409  2022       20            Juventude      22     38         3       13
#
#      derrotas  gols_marcados  gols_sofridos  saldo_de_gols  total_de_pontos  \
# ...

# %%
brasileirao.head()
# Out:
#     ano  posicao       equipe  pontos  jogos  vitorias  empates  derrotas  \
# 0  2003        1     Cruzeiro     100     46        31        7         8
# 1  2003        2       Santos      87     46        25       12         9
# 2  2003        3    São Paulo      78     46        22       12        12
# 3  2003        4  São Caetano      74     46        19       14        13
# 4  2003        5     Coritiba      73     46        21       10        15
#
#    gols_marcados  gols_sofridos  saldo_de_gols  total_de_pontos  \
# 0            102             47             55              138
# 1             93             60             33              138
# 2             81             67             14              138
# 3             53             37             16              138
# 4             67             58              9              138
#
#    aproveitamento
# 0           72.46
# 1           63.04
# 2           56.52
# 3           53.62
# 4           52.90

# %%
brasileirao.tail()
# Out:
#       ano  posicao               equipe  pontos  jogos  vitorias  empates  \
# 405  2022       16               Cuiabá      41     38        10       11
# 406  2022       17                Ceará      37     38         7       16
# 407  2022       18  Atlético Goianiense      36     38         8       12
# 408  2022       19                 Avaí      35     38         9        8
# 409  2022       20            Juventude      22     38         3       13
#
#      derrotas  gols_marcados  gols_sofridos  saldo_de_gols  total_de_pontos  \
# 405        17             31             42            -11              114
# 406        15             34             41             -7              114
# 407        18             39             57            -18              114
# 408        21             34             60            -26              114
# 409        22             29             69            -40              114
#
#      aproveitamento
# 405           35.96
# 406           32.46
# ...

# %% [markdown]
# <h3>Qual equipe venceu o campeonato mais vezes ao longo dos anos?</h3>

# %%
equipes_totais = brasileirao['equipe'].value_counts()

# %%
equipes_totais
# Out:
# São Paulo                 20
# Santos                    20
# Flamengo                  20
# Fluminense                20
# Corinthians               19
# Internacional             19
# Atlético Mineiro          19
# Grêmio                    18
# Cruzeiro                  17
# Palmeiras                 17
# Botafogo                  17
# Atlético Paranaense       15
# Vasco da Gama             15
# Coritiba                  14
# Goiás                     14
# Figueirense               11
# Bahia                     10
# Vitória                   10
# Ponte Preta                9
# Sport                      9
# Juventude                  7
# Chapecoense                7
# Avaí                       7
# Atlético Goianiense        7
# Ceará                      7
# Fortaleza                  7
# Paraná                     6
# Náutico                    5
# América Mineiro            5
# Criciúma                   4
# São Caetano                4
# Guarani                    3
# ...

# %%
equipes_totais_DF = equipes_totais.reset_index()

# %%
equipes_totais_DF
# Out:
#                      index  equipe
# 0                São Paulo      20
# 1                   Santos      20
# 2                 Flamengo      20
# 3               Fluminense      20
# 4              Corinthians      19
# 5            Internacional      19
# 6         Atlético Mineiro      19
# 7                   Grêmio      18
# 8                 Cruzeiro      17
# 9                Palmeiras      17
# 10                Botafogo      17
# 11     Atlético Paranaense      15
# 12           Vasco da Gama      15
# 13                Coritiba      14
# 14                   Goiás      14
# 15             Figueirense      11
# 16                   Bahia      10
# 17                 Vitória      10
# 18             Ponte Preta       9
# 19                   Sport       9
# 20               Juventude       7
# 21             Chapecoense       7
# 22                    Avaí       7
# 23     Atlético Goianiense       7
# 24                   Ceará       7
# 25               Fortaleza       7
# ...
